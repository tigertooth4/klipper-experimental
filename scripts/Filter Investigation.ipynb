import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt
import math

# %%
def plot_elbow_force(long_probe):
    
    force = long_probe["force"]
    sample_frequency = 400
    f0 = 60.0  # Frequency to be removed from signal (Hz)
    Q = 30  # Quality factor

# Design notch filter
    trim_left = 0
    trim = -250
    time = long_probe["time"]

    # figure 1
    fig, ax = plt.subplots(figsize=(10, 6))
    butter_fig1 = signal.butter(1, 76.0, 'highpass', fs=sample_frequency, output='sos')
    butter_force1 = signal.sosfilt(butter_fig1, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], butter_force1)
    plt.title("Figure 1 - Butterworth Highpass @ 76Hz")
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    # figure 2
    fig, ax = plt.subplots(figsize=(10, 6))
    b, a = signal.iirnotch(60.0, 30, sample_frequency)
    notch_sos_fig2 = signal.tf2sos(b, a)
    notch_force2 = signal.sosfiltfilt(notch_sos_fig2, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], notch_force2)
    plt.title("Figure 2 - Notch Filter @ 60Hz, Quality = 30")
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    # figure 3 - Notch filter
    trim = -1
    fig, ax = plt.subplots(figsize=(10, 6))
    b, a = signal.iirnotch(60.0, 1.0, sample_frequency)
    notch_sos_fig3 = signal.tf2sos(b, a)
    notch_force3 = signal.sosfilt(notch_sos_fig3, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], notch_force3)
    plt.title("Figure 3 - Notch Filter @ 60Hz, Quality=1")
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    # figure 3.1
    fig, ax = plt.subplots(figsize=(10, 6))
    b, a = signal.iirnotch(60.0, 2.0, sample_frequency)
    notch_sos_fig3 = signal.tf2sos(b, a)
    notch_force3 = signal.sosfiltfilt(notch_sos_fig3, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], notch_force3)
    plt.title("Figure 3.1 - Notch Filter @ 60Hz, Quality=2, filtfilt")
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    # figure 3.2
    fig, ax = plt.subplots(figsize=(10, 6))
    quality = 2.
    b1, a1 = signal.iirnotch(60.0, quality, sample_frequency)
    b2, a2 = signal.iirnotch(50.0, quality, sample_frequency)
    b = signal.convolve(b1, b2)
    a = signal.convolve(a1, a2)
    power_notch_filter = signal.tf2sos(b, a)
    notch_force3 = signal.sosfilt(power_notch_filter, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], notch_force3)
    plt.title("Figure 3.2 - Notch Filter @ 60Hz & 50Hz, Quality=%s" % (quality))
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    # figure 3.3
    fig, ax = plt.subplots(figsize=(10, 6))
    quality = 3.
    b1, a1 = signal.iirnotch(60.0, quality, sample_frequency)
    b2, a2 = signal.iirnotch(50.0, quality, sample_frequency)
    b = signal.convolve(b1, b2)
    a = signal.convolve(a1, a2)
    power_notch_filter = signal.tf2sos(b, a)
    notch_force3 = signal.sosfiltfilt(power_notch_filter, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], notch_force3)
    plt.title("Figure 3.4 - Notch Filter @ 60Hz & 50Hz, Quality=%s, filtfilt" % (quality))
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    # figure 3.4
    fig, ax = plt.subplots(figsize=(10, 6))
    quality = 1.
    b1, a1 = signal.iirnotch(60.0, quality, sample_frequency)
    b2, a2 = signal.iirnotch(50.0, quality, sample_frequency)
    b = signal.convolve(b1, b2)
    a = signal.convolve(a1, a2)
    power_notch_filter = signal.tf2sos(b, a)
    notch_force3 = signal.sosfiltfilt(power_notch_filter, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], notch_force3)
    plt.title("Figure 3.3 - Notch Filter @ 60Hz & 50Hz, Quality=%s, filtfilt" % (quality))
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    #figure 4 - Butterworth Bandstop
    fig, ax = plt.subplots(figsize=(10, 6))
    butter_sos = signal.butter(1, [50. - 16., 60. + 16.], 'bandstop', fs=sample_frequency, output='sos')
    butter_force = signal.sosfilt(butter_sos, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], butter_force)
    plt.title("Figure 4.1 - Butterworth Bandstop 50-60Hz, order=1")
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    fig, ax = plt.subplots(figsize=(10, 6))
    butter_sos = signal.butter(2, [50. - 16., 60. + 16.], 'bandstop', fs=sample_frequency, output='sos')
    butter_force = signal.sosfilt(butter_sos, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], butter_force)
    plt.title("Figure 4.2 - Butterworth Bandstop 50-60Hz, order=2")
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    fig, ax = plt.subplots(figsize=(10, 6))
    #trim = -1
    butter_sos = signal.butter(2, [50. - 16., 60. + 16.], 'bandstop', fs=sample_frequency, output='sos')
    butter_force = signal.sosfiltfilt(butter_sos, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], butter_force)
    plt.title("Figure 4.3 - Butterworth Bandstop 50-60Hz, order=2, filtfilt")
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

    #figure 4 - Butterworth Low Pass
    fig, ax = plt.subplots(figsize=(10, 6))
    butter_sos = signal.butter(2, 40.0, 'lowpass', fs=sample_frequency, output='sos')
    butter_force = signal.sosfiltfilt(butter_sos, force[trim_left:trim])
    ax.plot(time[trim_left:trim], force[trim_left:trim])
    ax.plot(time[trim_left:trim], butter_force)
    plt.title("Figure 4.1 - Butterworth Lowpass 30Hz, order=10")
    plt.ylabel("Force g")
    plt.xlabel("Time s")
    plt.show()

plot_elbow_force(long_probe)
#plot_elbow_force(long_probe_2)
